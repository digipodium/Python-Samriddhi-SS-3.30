# %%
word = "Hello World"
print(word)
# Out:
# Hello World

# %%
for i in word:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
print(word[5])

# %%
print(word[0:5])
# Out:
# Hello

# %%
str = "Beautiful is better than ugly"
print(str)
# Out:
# Beautiful is better than ugly

# %%
str.upper()
# Out:
# 'BEAUTIFUL IS BETTER THAN UGLY'

# %%
str.lower()
# Out:
# 'beautiful is better than ugly'

# %%
str.capitalize()
# Out:
# 'Beautiful is better than ugly'

# %%
str.title()
# Out:
# 'Beautiful Is Better Than Ugly'

# %%
str.find('pretty') #returns -1 if not found because index can't be negative
# Out:
# -1

# %%
sentence = str.replace("ugly", "beautiful").replace('better','worst')
print(sentence)
# Out:
# Beautiful is worst than beautiful
