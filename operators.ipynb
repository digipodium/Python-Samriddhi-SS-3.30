# %%
fruits = ["apple", "banana", "cherry"]
"mango" not in fruits
# Out:
# True

# %%
a = 20
b = 20
a is b
# Out:
# True

# %%
name = "Samriddhi"
type(name)
# Out:
# str

# %%
poem = '''Johny Johny yes papa
eating sugar no papa
telling a lie no papa
open your mouth hahaha'''
print(poem)
# Out:
# Johny Johny yes papa
# eating sugar no papa
# telling a lie no papa
# open your mouth hahaha

# %%
lst = [2,3,4,2,4,5,8]
print(lst)
# Out:
# [2, 3, 4, 2, 4, 5, 8]

# %%
a = {2,4,3,5,6,4,5,6,7,4,3,2}
print(a)
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
x = {'a','f','g','a','f','e'}
print(x)
# Out:
# {'e', 'g', 'a', 'f'}

# %%
student = {
    'name' : 'Samriddhi',
    'age' : 15,
    'class' : 10
}
print(student)
# Out:
# {'name': 'Samriddhi', 'age': 15, 'class': 10}
